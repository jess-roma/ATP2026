# %% [markdown]
# # Aula Prática 2 (guião)
# ### Semana de 21 a 25 de Setembro de 2026
# ### José Carlos Ramalho e Luís Cunha
# ### Sinopsis:
# Algoritmos de cálculo numérico envolvendo estruturas condicionais (if-elif-else) e cíclicas simples (while).

# %% [markdown]
# ### Exercício 1: Maior de 2 números
# - Especifique um programa que recebe dois valores e escreve na saída o maior.

# %%
n1= int(input("Insere o primeiro número:"))
n2= int(input("Insere o segundo número:"))
if n1>n2:
    print(f"O número {n1} é maior que {n2}")
elif n1==n2:
     print("Os números são iguais")
else:
      print(f"O número {n2} é maior que {n1}")
# Out:
# Os números são iguais

# %% [markdown]
# ### Exercício 2: Maior de 3 números
# - Especifique um programa que recebe três valores e escreve na saída o maior.

# %%
n1= int(input("Insere o primeiro número:"))
n2= int(input("Insere o segundo número:"))
n3= int(input("Insere o segundo número:"))
if n1<n3 and n2< n3:
    print(f"O número {n3} é maior que {n2} e {n1}")
elif n1<n2 and n3<n2:
    print(f"O número {n2} é maior que {n1} e {n3}")
elif n3<n1 and n2<n1:
    print(f"O número {n1} é maior que {n2} e {n3}")
else:
    print("Os números são iguais")
# Out:
# Os números são iguais

# %% [markdown]
# ### Exercício 3: Sobrinhos do Pato Donald
#
# - Especifique um programa que lê um nome e se este for `Hugo`, `Luís` ou `Zé` identifica-o como sobrinho do Pato Donald, se for outro nome deve indicar que o mesmo não é sobrinho de nínguém conhecido.

# %%
nome=input("Insire o teu nome:")
if nome== "Hugo" or nome=="Luís" or nome=="Zé":
    print(f"{nome} é sobrinho do Pato Donald!")
else:
    print(f"{nome} é não sobrinho(a) de ninguém conhecido.")
# Out:
# jess é não sobrinho(a) de ninguém conhecido.

# %% [markdown]
# ### Exercício 4: Índice de Massa Corporal
# - Especifique um programa que recebe dois parâmetros, **peso**,**altura**, calcula o IMC corresponente e interpreta esse resultado.
# - Input: 53 e 1.56
# - Output: "O seu índice de massa corporal é **21.78** e encontra-se na categoria **Normal**"
#
# Valores para a interpretação:
# - Menor que 18,5 - Baixo peso
# - 18,5 a 24,9 - Normal
# - 25 a 29,9	- Excesso de peso
# - 30 a 34,9	- Obesidade grau I
# - 35 a 39,9	- Obesidade grau II
# - Maior que 40	- Obesidade grau III

# %%
peso= float(input("Insira o seu peso (kg):"))
altura= float(input("Insira a sua altura (m):"))
imc= peso/altura**2
c= ""
if imc< 18.5:
    c= "Baixo peso"
elif 18.5<=imc<=24.9:
    c= "Normal"
elif 25<=imc<=29.9:
    c= "Excesso de peso"
elif 30<=imc<=34.9:
    c="Obesidade grau I"
elif 35<=imc<=39.9:
    c="Obesidade grau II"
else:
    c="Obesidade grau III"
print(f"O seu índice de massa corporal é {imc:.2f} e encontra-se na categoria {c}")
# Out:
# O seu índice de massa corporal é 18.52 e encontra-se na categoria Normal

# %% [markdown]
# ## Teoria: estrutura cíclica `while`
#
# Estrutura:
# ```python
#     while cond:
#         ação
#         ...
# ```

# %% [markdown]
# ### Exemplo: Somar os inteiros entre 1 e 10

# %%
soma = 0
i = 1
while i <= 10:
    soma = soma + i
    i = i + 1
print(soma)
# Out:
# 55

# %% [markdown]
# ### Exercício 5: Soma de N números
# - Leia um número N;
# - Leia N números;
# - Imprima a soma dos N números.

# %%
soma = 0
n = int(input("Quantos números pretende somar:"))
while n>0:
   num = int(input("Insira um número:"))
   soma= n+soma
   n=n-1
print(soma)
# Out:
# 6

# %% [markdown]
# ### Exercício 6: O Maior de N números
# - Leia um número N;
# - Leia N números;
# - Imprima o maior dos N números.

# %%
n = int(input("Quantos números pretende comparar:"))
maiorn=0
while n>0:
   num = int(input("Insira um número:"))
   n=n-1
   if maiorn < num:
     maiorn = num
     
print(maiorn)
# Out:
# 3

# %%
def maiorN(N):
    print(maiorN(3), maiorN(2))

# %% [markdown]
# ### Exercício 7: O Menor de N números
# - Leia um número N;
# - Leia N números;
# - Imprima o menor dos N números.

# %%
n=int(input("Quantos números pretendes comaparar:"))
n1= int(input("Insira um número:"))
while n>1:
    menorn=int(input("Insira o número:"))
    n-=1
    if n1<menorn:
        menorn= n1
print(f"O menor número é {n1}")
# Out:
# O menor número é 1

# %% [markdown]
# ### Exercício 8: A Média de N números
# - Leia um número N;
# - Leia N números;
# - Imprima a média dos N números.

# %%
# Solução do exercício 8
soma = 0
n = int(input("Quantos números pretende:"))
i=0
while n>0:
   num = int(input("Insira um número:"))
   soma= n+soma
   n=n-1
   i=i+1
media = soma/i
print(media)
# Out:
# 2.0

# %% [markdown]
# ## Teoria: definição de uma função `def`
#
# Estrutura:
# ```python
#     def f1(param1, param2, ..., paramn):
#         ação1
#         ação2
#         ...
#         return resultado
# ```

# %% [markdown]
# ### Exemplo: Somar os números inteiros de 1 até N

# %%
num = int(input("Introduza um número inteiro positivo:"))
def somatorio(num):
    return (num*(num+1)//2)
print(somatorio(num))
# Out:
# 6

# %% [markdown]
# ### Exercício 9:
#
# * Use a função definida no exemplo anterior para escrever no monitor uma lista de pares: (n, somatorio(n));
# * Faça n variar entre 10 e 1000 com um salto de 10: 10, 20, 30, ..., 1000.

# %%
# Função do somatório usando ciclo while
def somatorio(n):
    total= n*(n+1)//2
    return total

n = 10
while n <= 1000:
    print(f"({n}, {somatorio(n)})")
    n += 10
# Out:
# (10, 55)
# (20, 210)
# (30, 465)
# (40, 820)
# (50, 1275)
# (60, 1830)
# (70, 2485)
# (80, 3240)
# (90, 4095)
# (100, 5050)
# (110, 6105)
# (120, 7260)
# (130, 8515)
# (140, 9870)
# (150, 11325)
# (160, 12880)
# (170, 14535)
# (180, 16290)
# (190, 18145)
# (200, 20100)
# (210, 22155)
# (220, 24310)
# (230, 26565)
# (240, 28920)
# (250, 31375)
# (260, 33930)
# (270, 36585)
# (280, 39340)
# (290, 42195)
# (300, 45150)
# (310, 48205)
# (320, 51360)
# (330, 54615)
# (340, 57970)
# (350, 61425)
# (360, 64980)
# (370, 68635)
# (380, 72390)
# (390, 76245)
# (400, 80200)
# (410, 84255)
# (420, 88410)
# (430, 92665)
# (440, 97020)
# (450, 101475)
# (460, 106030)
# (470, 110685)
# (480, 115440)
# (490, 120295)
# (500, 125250)
# (510, 130305)
# (520, 135460)
# (530, 140715)
# (540, 146070)
# (550, 151525)
# (560, 157080)
# (570, 162735)
# (580, 168490)
# (590, 174345)
# (600, 180300)
# (610, 186355)
# (620, 192510)
# (630, 198765)
# (640, 205120)
# (650, 211575)
# (660, 218130)
# (670, 224785)
# (680, 231540)
# (690, 238395)
# (700, 245350)
# (710, 252405)
# (720, 259560)
# (730, 266815)
# (740, 274170)
# (750, 281625)
# (760, 289180)
# (770, 296835)
# (780, 304590)
# (790, 312445)
# (800, 320400)
# (810, 328455)
# (820, 336610)
# (830, 344865)
# (840, 353220)
# (850, 361675)
# (860, 370230)
# (870, 378885)
# (880, 387640)
# (890, 396495)
# (900, 405450)
# (910, 414505)
# (920, 423660)
# (930, 432915)
# (940, 442270)
# (950, 451725)
# (960, 461280)
# (970, 470935)
# (980, 480690)
# (990, 490545)
# (1000, 500500)

# %% [markdown]
# ### Exercício 10: Potência
# - Defina uma função **pot** que recebe dois parâmetros, **a** e **b**, e retorna o resultado de **a elevado à potência de b**.
# - Use esta função para escrever no monitor as potências de 2 com expoentes de 1 a 20.

# %%
# Solução do exercício 10

def pot(a,b):
    total= a**b
    return total
b=1
while b<=20 :
    print(pot(2,b))
    b+=1
# Out:
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
# 524288
# 1048576

# %% [markdown]
# #### Potências de base 2 com expoente entre 0  e 20

# %%
def expoente(a,b):
    total= a**b
    return total
b=0
while b!=21:
    print(expoente(2,b))
    b+=1
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
# 524288
# 1048576

# %% [markdown]
# ### Exercício 11: Série numérica
# - Defina uma função **serie** que recebe três parâmetros, **base**, **salto** e **nelems**, e escreve no monitor a série;
# - Invocada com: **serie(7, 4, 5)** escreveria: 7, 11, 15, 19, 23

# %%
# Solução do exercício 11
def serie(base,salto,nelems):
    while nelems>0:
        nelems-=1
        print(base)
        total=base+salto
        base= total  
base= int(input("Qual é a base?"))
salto= int(input("Qual é o salto?"))
nelems= int(input("Quais sãp as nelems?"))

serie(base,salto,nelems)
# Out:
# 7
# 11
# 15
# 19
# 23

# %% [markdown]
# ### Exercício 12: Desenhar um quadrado
# - Defina uma função **quad** que recebe um argumento, **n**, e desenha no monitor um quadrado usando o caráter '#';
# - O resultado da invocação dessa função com um argumento 3 deverá ser:
# ```
# ###
# ###
# ###
# ```

# %%
# Solução do exercício 12
n=int(input("Insira o lado do quadrado:"))
b=n
def quad(n,b):
    while n>0:
        print(b*"#")
        n-=1
quad(n,b)
# Out:
# #

# %% [markdown]
# ### Exercício 13: Desenhar um quadrado
# - Defina uma função que desenhe no ecran (usando os caracteres # e _) um tabuleiro de xadrez;
# - O resultado da invocação dessa função com um argumento 5 deverá ser:
# ```
# #_#_#
# _#_#_
# #_#_#
# _#_#_
# #_#_#
# ```

# %%
# Solução do exercício 13
n=int(input("Insira o lado do tabuleiro de xadrez:"))
cont=0
def chess(n,cont):
    while cont<n:
        if n%2==0:
            m=n//2
            if cont%2==0:
                print(m*"#_")
                cont+=1
            else: 
                 print(m*"_#")
                 cont+=1
        else:
            m=(n-1)//2
            if cont%2==0:
                print(m*"#_","#",sep="")
                cont+=1
            else: 
                print(m*"_#","_",sep="")
                cont+=1
chess(n,cont)
# Out:
# #_#_#_#_#_#
# _#_#_#_#_#_
# #_#_#_#_#_#
# _#_#_#_#_#_
# #_#_#_#_#_#
# _#_#_#_#_#_
# #_#_#_#_#_#
# _#_#_#_#_#_
# #_#_#_#_#_#
# _#_#_#_#_#_
# #_#_#_#_#_#

# %% [markdown]
# ### Exercício 14: Índice de Massa Corporal
# - Defina uma função **imc** que recebe dois parâmetros, **peso**,**altura**, calcula o IMC corresponente e interpreta esse resultado.
# - imc(53,1.56) - Output: "O seu índice de massa corporal é **21.78** e encontra-se na categoria **Normal**"
# - imc(83,1.56) - Output: "O seu índice de massa corporal é **34.11** e encontra-se na categoria **Obesidade grau I**"
#
# Valores:
# - Menor que 18,5 - Baixo peso
# - 18,5 a 24,9 - Normal
# - 25 a 29,9	- Excesso de peso
# - 30 a 34,9	- Obesidade grau I
# - 35 a 39,9	- Obesidade grau II
# - Maior que 40	- Obesidade grau III

# %%
# Solução do exercício 14
peso= float(input("Insira o seu peso (kg):"))
altura= float(input("Insira a sua altura (m):"))
imc= peso/altura**2
c= ""
if imc< 18.5:
    c= "Baixo peso"
elif 18.5<=imc<=24.9:
    c= "Normal"
elif 25<=imc<=29.9:
    c= "Excesso de peso"
elif 30<=imc<=34.9:
    c="Obesidade grau I"
elif 35<=imc<=39.9:
    c="Obesidade grau II"
else:
    c="Obesidade grau III"
print(f"O seu índice de massa corporal é {imc:.2f} e encontra-se na categoria {c}")

# %% [markdown]
# ### Exercício 15: Série de Fibonacci
# - Defina uma função **fib** que recebe um argumento, **n**, e escreve no monitor os primeiros n elementos da série de fibonacci;
# - A série de Fibonacci tem a seguinte definição matemática:
#     - Se n < 2 ==> 1
#     - Se n >= 2 ==> fib(n-1) + fib(n-2)

# %%
# Solução do exercício 15
n= int(input("Insira um número:"))
n1=1
def fib(n1):
    if n1<2:
        return 1
    else:
        return fib(n1-1)+fib(n1-2)
while n1<=n:
    print(fib(n1))
    n1+=1
# Out:
# 1
# 2
# 3
# 5
# 8
# 13
